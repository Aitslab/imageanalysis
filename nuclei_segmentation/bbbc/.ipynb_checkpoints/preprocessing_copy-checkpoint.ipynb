# %% [markdown]
# #### Imports

# %%
import glob
import os
import shutil
import zipfile
import requests
from config import config_vars

import os
import random

import matplotlib.pyplot as plt
import numpy as np

import pathlib
from tqdm import tqdm

import skimage.io
import skimage.segmentation

import utils.dirtools
import utils.augmentation

# %% [markdown]
# ## Download and unpack

# %% [markdown]
# #### Download zipfiles from BBBC

# %%
images = requests.get('https://data.broadinstitute.org/bbbc/BBBC039/images.zip')
masks = requests.get('https://data.broadinstitute.org/bbbc/BBBC039/masks.zip')
metadata = requests.get('https://data.broadinstitute.org/bbbc/BBBC039/metadata.zip')

# %% [markdown]
# #### Unpack images

# %%
images_zip = os.path.join(config_vars['raw_images_dir'], 'images.zip')
os.makedirs(config_vars['raw_images_dir'], exist_ok=True)
with open(images_zip, 'wb') as f:
    f.write(images.content)
    
zip_ref = zipfile.ZipFile(images_zip, 'r')
for file in zip_ref.namelist():
    if file.startswith('images/'):
        zip_ref.extract(file, config_vars['raw_images_dir'])

zip_ref.close()
os.remove(images_zip)

for file in glob.glob(os.path.join(config_vars['raw_images_dir'], 'images/*')):
    shutil.move(file, config_vars['raw_images_dir'])

shutil.rmtree(os.path.join(config_vars['raw_images_dir'], 'images'))

# %% [markdown]
# #### Extract annotations

# %%
masks_zip = os.path.join(config_vars['raw_annotations_dir'], 'masks.zip')
os.makedirs(config_vars['raw_annotations_dir'], exist_ok=True)
with open(masks_zip, 'wb') as f:
    f.write(masks.content)

zip_ref = zipfile.ZipFile(masks_zip, 'r')
for file in zip_ref.namelist():
    if file.startswith('masks/'):
        zip_ref.extract(file, config_vars['raw_annotations_dir'])

zip_ref.close()
os.remove(masks_zip)

for file in glob.glob(os.path.join(config_vars['raw_annotations_dir'], 'masks/*')):
    shutil.move(file, config_vars['raw_annotations_dir'])
shutil.rmtree(os.path.join(config_vars['raw_annotations_dir'], 'masks'))

# %% [markdown]
# #### Extract metadata

# %%
metadata_zip = os.path.join(config_vars['root_directory'], 'metadata.zip')
with open(metadata_zip, 'wb') as f:
    f.write(metadata.content)

zip_ref = zipfile.ZipFile(metadata_zip, 'r')
for file in zip_ref.namelist():
    if file.startswith('metadata/'):
        zip_ref.extract(file, config_vars['root_directory'])

zip_ref.close()
os.remove(metadata_zip)

for file in glob.glob(os.path.join(config_vars['root_directory'], 'metadata/*')):
    shutil.move(file, config_vars['root_directory'])
shutil.rmtree(os.path.join(config_vars['root_directory'], 'metadata'))

# %% [markdown]
# ## Preprocess images

# %% [markdown]
# #### Partition into training/validation

# %%
# Prepare split files

if config_vars["create_split_files"]:
    file_list = os.listdir(config_vars["raw_images_dir"])

    [list_training, list_test, list_validation] = utils.dirtools.create_image_lists(
        config_vars["raw_images_dir"],
        config_vars["training_fraction"],
        config_vars["validation_fraction"]
    )

    utils.dirtools.write_path_files(config_vars["path_files_training"], list_training)
    utils.dirtools.write_path_files(config_vars["path_files_test"], list_test)
    utils.dirtools.write_path_files(config_vars["path_files_validation"], list_validation)
    
data_partitions = utils.dirtools.read_data_partitions(config_vars, load_augmented=False)

# %%
# Create output directories for transformed data

os.makedirs(config_vars["normalized_images_dir"], exist_ok=True)
os.makedirs(config_vars["boundary_labels_dir"], exist_ok=True)

# %% [markdown]
# #### Transform to png

# %%
if config_vars["transform_images_to_PNG"]:
    
    filelist = sorted(os.listdir(config_vars["raw_images_dir"]))

    # run over all raw images
    for filename in tqdm(filelist):

        # load image and its annotation
        orig_img = skimage.io.imread(config_vars["raw_images_dir"] + filename)       

        # IMAGE

        # normalize to [0,1]
        percentile = 99.9
        high = np.percentile(orig_img, percentile)
        low = np.percentile(orig_img, 100-percentile)

        img = np.minimum(high, orig_img)
        img = np.maximum(low, img)

        img = (img - low) / (high - low) # gives float64, thus cast to 8 bit later
        img = skimage.img_as_ubyte(img) 

        skimage.io.imsave(config_vars["normalized_images_dir"] + filename[:-3] + 'png', img)    
else:
    config_vars["normalized_images_dir"] = config_vars["raw_images_dir"]
# Out:
# 100%|██████████| 200/200 [00:31<00:00,  6.29it/s]

# %%
print(img.dtype, img.shape)
filename = os.listdir(config_vars["normalized_images_dir"])
img = skimage.io.imread(config_vars["normalized_images_dir"] + filename[-1])
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
plt.hist(img.flatten(), bins=100)
plt.show()
# Out:
# uint8 (520, 696)

# %% [markdown]
# #### Output targets: three class boundary

# %%
filelist = sorted(os.listdir(config_vars["raw_annotations_dir"]))
total_objects = 0

# run over all raw images
for filename in tqdm(filelist):
    
    # GET ANNOTATION
    annot = skimage.io.imread(config_vars["raw_annotations_dir"] + filename)
    
    # strip the first channel
    if len(annot.shape) == 3:
        annot = annot[:,:,0]
    
    # label the annotations nicely to prepare for future filtering operation
    annot = skimage.morphology.label(annot)
    total_objects += len(np.unique(annot)) - 1
    
    # filter small objects, e.g. micronulcei
    annot = skimage.morphology.remove_small_objects(annot, min_size=config_vars["min_nucleus_size"])
    
    # find boundaries
    boundaries = skimage.segmentation.find_boundaries(annot)

    for k in range(2, config_vars["boundary_size"], 2):
        boundaries = skimage.morphology.binary_dilation(boundaries)
        
    # BINARY LABEL
    
    # prepare buffer for binary label
    label_binary = np.zeros((annot.shape + (3,)))
    
    # write binary label
    label_binary[(annot == 0) & (boundaries == 0), 0] = 1
    label_binary[(annot != 0) & (boundaries == 0), 1] = 1
    label_binary[boundaries == 1, 2] = 1
    
    # save it - converts image to range from 0 to 255
    skimage.io.imsave(config_vars["boundary_labels_dir"] + filename, label_binary)
    
print("Total objects: ",total_objects)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   0%|          | 1/200 [00:00<00:34,  5.75it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|          | 2/200 [00:00<00:32,  6.14it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|▏         | 3/200 [00:00<00:32,  6.01it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|▎         | 5/200 [00:00<00:30,  6.48it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   3%|▎         | 6/200 [00:00<00:29,  6.56it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|▎         | 7/200 [00:01<00:29,  6.52it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|▍         | 8/200 [00:01<00:29,  6.53it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|▍         | 9/200 [00:01<00:29,  6.45it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   5%|▌         | 10/200 [00:01<00:28,  6.75it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|▌         | 11/200 [00:01<00:27,  6.83it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|▌         | 12/200 [00:01<00:25,  7.24it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|▋         | 13/200 [00:01<00:25,  7.41it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   7%|▋         | 14/200 [00:02<00:26,  7.03it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|▊         | 15/200 [00:02<00:26,  6.92it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|▊         | 16/200 [00:02<00:27,  6.73it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|▊         | 17/200 [00:02<00:27,  6.68it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   9%|▉         | 18/200 [00:02<00:27,  6.58it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|▉         | 19/200 [00:02<00:27,  6.68it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|█         | 20/200 [00:02<00:26,  6.69it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|█         | 21/200 [00:03<00:26,  6.77it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  11%|█         | 22/200 [00:03<00:27,  6.41it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█▏        | 23/200 [00:03<00:27,  6.43it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█▏        | 24/200 [00:03<00:27,  6.46it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|
/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  72%|███████▎  | 145/200 [00:22<00:08,  6.42it/s]/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: /home/jupyter/boundary_labels/IXMtest_L10_s6_w12D12D64C-2639-4CA8-9BB4-99F92C9B7068.png is a low contrast image
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|███████▎  | 147/200 [00:22<00:07,  7.04it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|███████▍  | 148/200 [00:22<00:07,  6.71it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|███████▍  | 149/200 [00:22<00:07,  6.38it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  75%|███████▌  | 150/200 [00:22<00:07,  6.29it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|███████▌  | 151/200 [00:22<00:07,  6.61it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|███████▌  | 152/200 [00:23<00:07,  6.43it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|███████▋  | 153/200 [00:23<00:07,  6.28it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  77%|███████▋  | 154/200 [00:23<00:07,  6.09it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|███████▊  | 155/200 [00:23<00:07,  6.14it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|███████▊  | 156/200 [00:23<00:06,  6.57it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|███████▊  | 157/200 [00:23<00:06,  6.44it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  79%|███████▉  | 158/200 [00:24<00:06,  6.23it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|███████▉  | 159/200 [00:24<00:06,  6.20it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|████████  | 160/200 [00:24<00:06,  6.22it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|████████  | 161/200 [00:24<00:06,  6.43it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  81%|████████  | 162/200 [00:24<00:06,  6.23it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████▏ | 163/200 [00:24<00:06,  6.17it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████▏ | 164/200 [00:24<00:05,  6.29it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████▎ | 165/200 [00:25<00:05,  6.39it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  83%|████████▎ | 166/200 [00:25<00:05,  6.40it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  84%|████████▎ | 167/200 [00:25<00:05,  6.32it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  84%|████████▍ | 169/200 [00:25<00:04,  6.85it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  85%|████████▌ | 170/200 [00:25<00:04,  7.15it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|████████▌ | 171/200 [00:25<00:03,  7.27it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|████████▌ | 172/200 [00:26<00:03,  7.38it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|████████▋ | 173/200 [00:26<00:03,  7.21it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  87%|████████▋ | 174/200 [00:26<00:03,  7.15it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  88%|████████▊ | 175/200 [00:26<00:03,  7.10it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  88%|████████▊ | 176/200 [00:26<00:03,  7.16it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  89%|████████▉ | 178/200 [00:26<00:02,  8.19it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  90%|█████████ | 180/200 [00:27<00:02,  8.17it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  90%|█████████ | 181/200 [00:27<00:02,  7.43it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  91%|█████████ | 182/200 [00:27<00:02,  6.97it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████▏| 183/200 [00:27<00:02,  6.69it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████▏| 184/200 [00:27<00:02,  6.62it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████▎| 185/200 [00:27<00:02,  6.97it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  93%|█████████▎| 186/200 [00:28<00:02,  6.60it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  94%|█████████▎| 187/200 [00:28<00:01,  6.64it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  94%|█████████▍| 188/200 [00:28<00:01,  7.25it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  95%|█████████▌| 190/200 [00:28<00:01,  7.88it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|█████████▌| 191/200 [00:28<00:01,  7.32it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|█████████▌| 192/200 [00:28<00:01,  7.29it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|█████████▋| 193/200 [00:28<00:00,  7.19it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  97%|█████████▋| 194/200 [00:29<00:00,  7.35it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|█████████▊| 195/200 [00:29<00:00,  7.14it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|█████████▊| 196/200 [00:29<00:00,  7.46it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|█████████▊| 197/200 [00:29<00:00,  7.18it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|█████████▉| 199/200 [00:29<00:00,  7.59it/s]Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|██████████| 200/200 [00:29<00:00,  6.70it/s]
# Total objects:  23615

# %%
# Show example image 
print(annot.dtype, annot.shape)

# plot original annotation
plt.figure(figsize=(10,10))
plt.imshow(annot, cmap="nipy_spectral")
plt.show()

# plot boundary labels
plt.figure(figsize=(10,10))
plt.imshow(label_binary)
plt.show()
# Out:
# int64 (520, 696)
