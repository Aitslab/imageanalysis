# %% [markdown]
# #### Imports

# %%
import sys
import os
import os.path

import numpy as np
import skimage.io
import glob

import shutil
#from config import config_vars

from tqdm import tqdm

import matplotlib.pyplot as plt
import skimage.morphology

import tensorflow as tf
import keras

import utils.metrics
import utils.model_builder
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Prerequisites
# > First step is to convert from C01 to tiff using "convert-images-to-tiff-updated.ipynb"
# >
# > Put the tiff-files in a directory and change the paths below

# %% [markdown]
# #### Convert from tiff to png + normalize

# %%
flist = sorted(os.listdir('/home/jupyter/aitslab_images'))

fdir = '/home/jupyter/aitslab_images/'

# run over all raw images
for filename in tqdm(flist):
    if filename != ".ipynb_checkpoints" and filename != "norm_images":

        # load image and its annotation
        orig_img = skimage.io.imread(fdir + filename, plugin='matplotlib')       

        # IMAGE

        # normalize to [0,1]
        percentile = 99.9
        high = np.percentile(orig_img, percentile)
        low = np.percentile(orig_img, 100-percentile)

        img = np.minimum(high, orig_img)
        img = np.maximum(low, img)

        img = (img - low) / (high - low) # gives float64, thus cast to 8 bit later
        img = skimage.img_as_ubyte(img) 

        skimage.io.imsave(fdir + "/norm_images/" + filename[:-4] + 'png', img)

# %% [markdown]
# #### View result:

# %%
filename = os.listdir('/home/jupyter/aitslab_images/norm_images')

img = skimage.io.imread('/home/jupyter/aitslab_images/norm_images/' + filename[-1])
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
plt.hist(img.flatten(), bins=100)
plt.show()

# %%
print(img.dtype, img.shape)
# Out:
# uint8 (1104, 1104)

# %% [markdown]
# #### Compare to BBBC images

# %%
from config import config_vars

# %%
print(img.dtype, img.shape)
filename = os.listdir(config_vars["normalized_images_dir"])
img = skimage.io.imread(config_vars["normalized_images_dir"] + filename[-1])
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
plt.hist(img.flatten(), bins=100)
plt.show()
# Out:
# uint8 (1104, 1104)

# %% [markdown]
# ## Make predictions

# %% [markdown]
# #### Config

# %%
from config import config_vars

# Partition of the data to make predictions (test or validation)
#partition = "validation"

experiment_name = 'aits'

config_vars = utils.dirtools.setup_experiment(config_vars, experiment_name)

data_partitions = utils.dirtools.read_data_partitions(config_vars)

config_vars
# Out:
# {'root_directory': '/home/jupyter',
#  'max_training_images': 0,
#  'create_split_files': False,
#  'training_fraction': 0.5,
#  'validation_fraction': 0.25,
#  'transform_images_to_PNG': True,
#  'pixel_depth': 8,
#  'min_nucleus_size': 25,
#  'boundary_size': 2,
#  'augment_images': False,
#  'elastic_points': 16,
#  'elastic_distortion': 5,
#  'elastic_augmentations': 10,
#  'learning_rate': 0.0001,
#  'epochs': 15,
#  'steps_per_epoch': 500,
#  'batch_size': 10,
#  'val_batch_size': 10,
#  'rescale_labels': True,
#  'crop_size': 256,
#  'cell_min_size': 16,
#  'boundary_boost_factor': 1,
#  'object_dilation': 3,
#  'raw_images_dir': '/home/jupyter/raw_images/',
#  'raw_annotations_dir': '/home/jupyter/raw_annotations/',
#  'path_files_training': '/home/jupyter/training.txt',
#  'path_files_validation': '/home/jupyter/validation.txt',
#  'path_files_test': '/home/jupyter/test.txt',
#  'normalized_images_dir': '/home/jupyter/norm_images/',
#  'boundary_labels_dir': '/home/jupyter/boundary_labels/',
#  'experiment_dir': '/home/jupyter/experiments/aits/out/',
#  'probmap_out_dir': '/home/jupyter/experiments/aits/out/prob/',
#  'labels_out_dir': '/home/jupyter/experiments/aits/out/segm/',
#  'model_file': '/home/jupyter/experiments/aits/model.hdf5',
#  'csv_log_file': '/home/jupyter/experiments/aits/log.csv'}

# %%
# Use the following configuration if you want to test on CPUs
# os.environ['CUDA_VISIBLE_DEVICES'] = ''
# configuration = tf.ConfigProto(
#       intra_op_parallelism_threads=1,
#       inter_op_parallelism_threads=1)

configuration = tf.compat.v1.ConfigProto()
configuration.gpu_options.allow_growth = True
configuration.gpu_options.visible_device_list = "0"
session = tf.compat.v1.Session(config = configuration)

# apply session
session = tf.compat.v1.keras.backend.set_session(session)

# apply session
tf.compat.v1.keras.backend.set_session(session)

# %% [markdown]
# #### preprocess images and load model

# %%
filename = os.listdir('/home/jupyter/aitslab_images/norm_images')

# %%
#image_names = [f for f in data_partitions[partition] if f.startswith("IXM")]
#image_names = [os.path.join(config_vars["normalized_images_dir"], f) for f in data_partitions[partition]]

image_names = [os.path.join('/home/jupyter/aitslab_images/norm_images', f) for f in filename]
image_names.remove('/home/jupyter/aitslab_images/norm_images/.ipynb_checkpoints')

imagebuffer = skimage.io.imread_collection(image_names)

images = imagebuffer.concatenate()

dim1 = images.shape[1]
dim2 = images.shape[2]

images = images.reshape((-1, dim1, dim2, 1))

# preprocess (assuming images are encoded as 8-bits in the preprocessing step)
images = images / 255

# build model and load weights
model = utils.model_builder.get_model_3_class(dim1, dim2)
#model.load_weights(config_vars["model_file"])
model.load_weights('/home/jupyter/experiments/01/model.hdf5')

# Normal prediction time
predictions = model.predict(images, batch_size=1)

model.summary()
# Out:
# /home/jupyter/utils/model_builder.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   a = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(x)
# /home/jupyter/utils/model_builder.py:17: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   a = keras.layers.BatchNormalization(**option_dict_bn)(a)
# /home/jupyter/utils/model_builder.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   a = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(a)
# /home/jupyter/utils/model_builder.py:20: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   a = keras.layers.BatchNormalization(**option_dict_bn)(a)
# /home/jupyter/utils/model_builder.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   b = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(y)
# /home/jupyter/utils/model_builder.py:26: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   b = keras.layers.BatchNormalization(**option_dict_bn)(b)
# /home/jupyter/utils/model_builder.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   b = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(b)
# /home/jupyter/utils/model_builder.py:29: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   b = keras.layers.BatchNormalization(**option_dict_bn)(b)
# /home/jupyter/utils/model_builder.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   c = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(y)
# /home/jupyter/utils/model_builder.py:35: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   c = keras.layers.BatchNormalization(**option_dict_bn)(c)
# /home/jupyter/utils/model_builder.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   c = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(c)
# /home/jupyter/utils/model_builder.py:38: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   c = keras.layers.BatchNormalization(**option_dict_bn)(c)
# /home/jupyter/utils/model_builder.py:43: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", padding="same")`
#   d = keras.layers.Convolution2D(512, 3, 3, **option_dict_conv)(y)
# /home/jupyter/utils/model_builder.py:44: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   d = keras.layers.BatchNormalization(**option_dict_bn)(d)
# /home/jupyter/utils/model_builder.py:46: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", padding="same")`
#   d = keras.layers.Convolution2D(512, 3, 3, **option_dict_conv)(d)
# /home/jupyter/utils/model_builder.py:47: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   d = keras.layers.BatchNormalization(**option_dict_bn)(d)
# /home/jupyter/utils/model_builder.py:56: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   e = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(y)
# /home/jupyter/utils/model_builder.py:57: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   e = keras.layers.BatchNormalization(**option_dict_bn)(e)
# /home/jupyter/utils/model_builder.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   e = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(e)
# /home/jupyter/utils/model_builder.py:60: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   e = keras.layers.BatchNormalization(**option_dict_bn)(e)
# /home/jupyter/utils/model_builder.py:67: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   f = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(y)
# /home/jupyter/utils/model_builder.py:68: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   f = keras.layers.BatchNormalization(**option_dict_bn)(f)
# /home/jupyter/utils/model_builder.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   f = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(f)
# /home/jupyter/utils/model_builder.py:71: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   f = keras.layers.BatchNormalization(**option_dict_bn)(f)
# /home/jupyter/utils/model_builder.py:78: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(y)
# /home/jupyter/utils/model_builder.py:79: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   y = keras.layers.BatchNormalization(**option_dict_bn)(y)
# /home/jupyter/utils/model_builder.py:81: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(y)
# /home/jupyter/utils/model_builder.py:82: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   y = keras.layers.BatchNormalization(**option_dict_bn)(y)
# /home/jupyter/utils/model_builder.py:91: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (1, 1), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(3, 1, 1, **option_dict_conv)(y)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1104, 1104, 1 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 1104, 1104, 6 640         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1104, 1104, 6 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1104, 1104, 6 36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1104, 1104, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 552, 552, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 552, 552, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 552, 552, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 552, 552, 128 147584      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 552, 552, 128 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 276, 276, 128 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 276, 276, 256 295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 276, 276, 256 1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 276, 276, 256 590080      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 276, 276, 256 1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 138, 138, 256 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 138, 138, 512 1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 138, 138, 512 2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 138, 138, 512 2359808     batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 138, 138, 512 2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 276, 276, 512 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 276, 276, 768 0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 276, 276, 256 1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 276, 276, 256 1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 276, 276, 256 590080      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 276, 276, 256 1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 552, 552, 256 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 552, 552, 384 0           up_sampling2d_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 552, 552, 128 442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 552, 552, 128 512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 552, 552, 128 147584      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 552, 552, 128 512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 1104, 1104, 1 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1104, 1104, 1 0           up_sampling2d_3[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1104, 1104, 6 110656      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1104, 1104, 6 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1104, 1104, 6 36928       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1104, 1104, 6 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1104, 1104, 3 195         batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1104, 1104, 3 0           conv2d_15[0][0]
# ==================================================================================================
# Total params: 7,793,155
# Trainable params: 7,787,523
# Non-trainable params: 5,632
# __________________________________________________________________________________________________

# %% [markdown]
# #### Plot prob map, predictions and labels

# %%
for i in range(len(images)):

    filename = imagebuffer.files[i]
    filename = os.path.basename(filename)
    print(filename)
    
    probmap = predictions[i].squeeze()
    
    plt.imshow(probmap)
    plt.show()
    
    skimage.io.imsave(config_vars["probmap_out_dir"] + filename, probmap)
    
    pred = utils.metrics.probmap_to_pred(probmap, config_vars["boundary_boost_factor"])

    plt.imshow(pred)
    plt.show()
    
    label = utils.metrics.pred_to_label(pred, config_vars["cell_min_size"])
    
    plt.imshow(label)
    plt.show()
    
    skimage.io.imsave(config_vars["labels_out_dir"] + filename, label)
# Out:
# MFGTMPcx7_170803210001_A01f29d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_A01f29d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 112]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_A05f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_A05f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 26]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_B18f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_B18f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 80]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_B19f26d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_B19f26d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 110]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_D04f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_D04f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 107]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_I06f29d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_I06f29d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 92]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_I07f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_I07f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 66]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_J12f29d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_J12f29d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 99]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_L13f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_L13f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 90]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_L14f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_L14f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 62]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_O09f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_O09f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 33]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_P09f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_P09f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 23]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_P17f28d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_P17f28d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 54]. Convert image to uint8 prior to saving to suppress this warning.
# MFGTMPcx7_170803210001_P22f27d0.png
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: /home/jupyter/experiments/aits/out/segm/MFGTMPcx7_170803210001_P22f27d0.png is a low contrast image
# Lossy conversion from int64 to uint8. Range [0, 66]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# #### Comparison between ground truth and prediction

# %%
f, axs = plt.subplots(1,2,figsize=(15,15))

filename = os.listdir('/home/jupyter/aitslab_images/norm_images')
img = skimage.io.imread('/home/jupyter/aitslab_images/norm_images/' + filename[-1])

filename2 = os.listdir('/home/jupyter/experiments/aits/out/segm')
img2 = skimage.io.imread('/home/jupyter/experiments/aits/out/segm/' + filename[-1])



axs[0].imshow(img)
axs[1].imshow(img2)

# %%
f, axs = plt.subplots(1,2,figsize=(15,15))

filename = os.listdir('/home/jupyter/aitslab_images/norm_images')
img = skimage.io.imread('/home/jupyter/aitslab_images/norm_images/' + filename[-2])

filename2 = os.listdir('/home/jupyter/experiments/aits/out/segm')
img2 = skimage.io.imread('/home/jupyter/experiments/aits/out/segm/' + filename[-2])



axs[0].imshow(img)
axs[1].imshow(img2)
