# %%
import skimage
import skimage.io
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
import os

# %% [markdown]
# # **Nuclei-annotationset-2**
#
# ## Nuclei-annotationset-1 with correction after on Sonjas inspection

# %% [markdown]
# ## Images can be found in
#
# /lunarc/nobackup/projects/snic2020-6-41/Shared_data/data//lunarc/nobackup/projects/snic2020-6-41/Shared_data/data_segmentation_project_Malou/

# %%
masks_path = '/home/malou/Master/data/Annotationsets/Nuclei-annotationset-2/'
norm_path = '/home/malou/Master/data/2_nuclei_ch_images/norm_images/'
masks = os.listdir(masks_path)
norm_im = os.listdir(norm_path)


for image in masks:
    
    mask = skimage.io.imread(masks_path + image)
    norm = skimage.io.imread(norm_path + image)
    display(Markdown("# <div align='center'>{}</div>".format(image)))
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10,10))
    #fig.suptitle(masks[0])
    ax1.imshow(mask)
    ax2.imshow(norm)
    ax1.tick_params(axis='both', labelsize=0, length = 0)
    ax2.tick_params(axis='both', labelsize=0, length = 0)
    plt.show()
# Out:
# # <div align='center'>MFGTMPcx7_170731090001_I12f07d0.png</div>
# # <div align='center'>MFGTMPcx7_170731090001_G15f00d0.png</div>
# # <div align='center'>MFGTMPcx7_170702000001_B23f07d0.png</div>
# # <div align='center'>MFGTMPcx7_170702090001_C09f01d0.png</div>
# # <div align='center'>MFGTMPcx7_170802000001_I10f05d0.png</div>
# # <div align='center'>MFGTMPcx7_170702090001_K22f04d0.png</div>
# # <div align='center'>MFGTMPcx7_170731090001_G15f03d0.png</div>
# # <div align='center'>MFGTMPcx7_170702090001_A10f11d0.png</div>
# # <div align='center'>MFGTMPcx7_170702090001_A08f12d0.png</div>
# # <div align='center'>MFGTMPcx7_170702000001_F11f10d0.png</div>
# # <div align='center'>MFGTMPcx7_170702090001_N06f14d0.png</div>
# # <div align='center'>MFGTMPcx7_170731090001_K05f07d0.png</div>
# # <div align='center'>MFGTMPcx7_170702090001_P01f02d0.png</div>
# # <div align='center'>MFGTMPcx7_170731090001_B14f13d0.png</div>
# # <div align='center'>MFGTMPcx7_170702090001_O02f15d0.png</div>
# ...
